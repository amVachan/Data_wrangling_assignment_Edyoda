# %%
import numpy as np
import pandas as pd

# %%
# importing dataset from the url 
covid_data = pd.read_csv('https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv')

# %%
covid_data.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
# no. of rows and columns in the dataset
covid_data.shape
# Out:
# (57394, 49)

# %%
# datatypes of all the columns
covid_data.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
# info of the covid_data dataframe
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
# description of covid_data dataframe
covid_data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
# count of unique values in location column
covid_data['location'].nunique()
# Out:
# 216

# %%
# continent having maximum frequency
covid_data['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
# maximum and mean values in total_cases column
print('maximum cases: '+str(covid_data['total_cases'].max()))
print('mean of total cases: '+str(covid_data['total_cases'].mean()))
# Out:
# maximum cases: 55154651.0
# mean of total cases: 167797.3688753302

# %%
# 25%, 50% and 75% quartile of total deaths
print('25% quartile: '+str(covid_data['total_deaths'].quantile(q=0.25)))
print('50% quartile: '+str(covid_data['total_deaths'].quantile(q=0.50)))
print('75% quartile: '+str(covid_data['total_deaths'].quantile(q=0.75)))
# Out:
# 25% quartile: 13.0
# 50% quartile: 84.0
# 75% quartile: 727.0

# %%
# continent having maximum human_development_index
max=covid_data['human_development_index'].max()
covid_data[covid_data['human_development_index']==max]['continent'].unique()
# Out:
# array(['Europe'], dtype=object)

# %%
covid_data.groupby('continent')['human_development_index'].max()
# Out:
# continent
# Africa           0.797
# Asia             0.933
# Europe           0.953
# North America    0.926
# Oceania          0.939
# South America    0.843
# Name: human_development_index, dtype: float64

# %%
# continent having maximum human_development_index
max=covid_data['gdp_per_capita'].min()
covid_data[covid_data['gdp_per_capita']==max]['continent'].unique()
# Out:
# array(['Africa'], dtype=object)

# %%
# filtering the dataframe
covid_data=covid_data.filter(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])

# %%
covid_data
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# removing duplicate observations
covid_data.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# finding missing values in dataframe 
covid_data.isna().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
# removing all observations where continent value is missing
covid_data.dropna(subset=['continent'],inplace=True)

# %%
# filling all the missing value with 0
covid_data.fillna(0,inplace=True)

# %% [markdown]
# ## DateTime Format

# %%
# converting date coulumn datetime format
covid_data['date']=pd.to_datetime(covid_data['date'])

# %%
covid_data
# Out:
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# creating a month column from date column
covid_data['month']=covid_data['date'].dt.month

# %%
covid_data
# Out:
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# ...

# %% [markdown]
# ## Data Aggregation

# %%
# finding max values in all columns 
df_groupby = covid_data.groupby('continent').max()

# %%
df_groupby=df_groupby.reset_index()

# %%
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12

# %% [markdown]
# ## Feature Engineering

# %%
# new column total_deaths_to_total_cases by ratio of total_deaths column to total_cases column
df_groupby['total_deaths_total_cases']=df_groupby['total_deaths']/df_groupby['total_cases']

# %%
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month  \
# 0       20314.0       26382.287                    0.797     12
# 1      130519.0      116935.600                    0.933     12
# 2       52147.0       94277.965                    0.953     12
# 3      247220.0       54225.446                    0.926     12
# 4         907.0       44648.710                    0.939     12
# 5      166014.0       22767.037                    0.843     12
#
# ...

# %% [markdown]
# ## DataVisualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df_groupby['gdp_per_capita'])
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
sns.scatterplot(x=df_groupby['total_cases'],y=df_groupby['gdp_per_capita'])
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='gdp_per_capita'>

# %%
sns.pairplot(df_groupby)

# %%
sns.catplot(data=df_groupby,x='continent',y='total_cases')

# %%
# saving the dataframe to a csv file
df_groupby.to_csv('covid_csv',index=False)
